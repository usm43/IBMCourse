# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Usman's Notebook

# %% [markdown]
# This is my notebook.

# %% [markdown]
# Data science languages are Python and R.

# %% [markdown]
# Data science libraries include Pandas and matplotlib.

# %% [markdown]
# Data science tools include Jupyter Notebook and Git.

# %% [markdown]
# Arithmetic expressions include something like 2 + 2.

# %%
2 * (2+2)
# Out:
# 8

# %%
# minutes to hours
minutes = int(input("Minutes?: "))
hours = minutes / 60

print(hours)
# Out:
# 2.0

# %% [markdown]
# Objectives are to complete this course.

# %% [markdown]
# The author is Usman Shahid
